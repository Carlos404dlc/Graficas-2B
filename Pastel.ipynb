# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos404dlc/Graficas-2B/blob/main/Pastel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sizes = [250, 250, 300, 200 ] # Alumnos con calificaciones bajas, medias y altas
labels = ['Bajas', 'Medio bajo', 'Altas','muy Altas']
colors = ['green', 'orange', 'red', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Diagrama de Pastel: Calificaciones')
plt.show()
