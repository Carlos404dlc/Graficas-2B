# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos404dlc/Graficas-2B/blob/main/dispersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = np.random.uniform(6, 20, 50) # Horas de estudio
y = 5 * x + np.random.normal(scale=5, size=50) # Calificaciones con algo de ruido
plt.scatter(x, y, color='black', alpha=0.7)
plt.title('Diagrama de Dispersión: Estudio vs Calificaciones')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')
plt.show()
